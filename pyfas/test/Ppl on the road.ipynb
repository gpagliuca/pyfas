# %%
import pyfas as fa

# %%
ppl = fa.Ppl("FC1_rev01.ppl")

# %%
ppl.profiles
# Out:
# {1: "GG 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Gas mass flow'\n",
#  2: "GLT 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Total liquid mass flow'\n",
#  3: "GT 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Total mass flow'\n",
#  4: "PT 'SECTION:' 'BRANCH:' 'old_offshore' '(PA)' 'Pressure'\n",
#  5: "TM 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Fluid temperature'\n",
#  6: "TWS 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Inner wall surface temperature'\n",
#  7: "TWSO 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Outer wall surface temperature'\n",
#  8: "HOL 'SECTION:' 'BRANCH:' 'old_offshore' '(-)' 'Holdup (liquid volume fraction)'\n",
#  9: "GG 'BOUNDARY:' 'BRANCH:' 'riser' '(KG/S)' 'Gas mass flow'\n",
#  10: "GLT 'BOUNDARY:' 'BRANCH:' 'riser' '(KG/S)' 'Total liquid mass flow'\n",
#  11: "GT 'BOUNDARY:' 'BRANCH:' 'riser' '(KG/S)' 'Total mass flow'\n",
#  12: "PT 'SECTION:' 'BRANCH:' 'riser' '(PA)' 'Pressure'\n",
# ...

# %%
ppl.filter_profiles('old')
# Out:
# {-314: "'old_offshore'\n",
#  1: "GG 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Gas mass flow'\n",
#  2: "GLT 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Total liquid mass flow'\n",
#  3: "GT 'BOUNDARY:' 'BRANCH:' 'old_offshore' '(KG/S)' 'Total mass flow'\n",
#  4: "PT 'SECTION:' 'BRANCH:' 'old_offshore' '(PA)' 'Pressure'\n",
#  5: "TM 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Fluid temperature'\n",
#  6: "TWS 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Inner wall surface temperature'\n",
#  7: "TWSO 'SECTION:' 'BRANCH:' 'old_offshore' '(C)' 'Outer wall surface temperature'\n",
#  8: "HOL 'SECTION:' 'BRANCH:' 'old_offshore' '(-)' 'Holdup (liquid volume fraction)'\n",
#  16: "HOL 'SECTION:' 'BRANCH:' 'riser' '(-)' 'Holdup (liquid volume fraction)'\n",
#  24: "HOL 'SECTION:' 'BRANCH:' 'new_offshore' '(-)' 'Holdup (liquid volume fraction)'\n",
#  32: "HOL 'SECTION:' 'BRANCH:' 'to_vent' '(-)' 'Holdup (liquid volume fraction)'\n",
# ...

# %%
ppl.extract_geometry('old_offshore')

# %%
ppl.geometries
# Out:
# {'old_offshore': ([0.0,
#    50.163,
#    101.329,
#    151.23,
#    201.132,
#    251.084,
#    301.035,
#    350.937,
#    400.838,
#    470.98,
#    551.142,
#    651.344,
#    776.248,
#    901.151,
#    1026.104,
#    1151.057,
#    1275.96,
#    1400.863,
#    1526.113,
#    1651.364,
#    1776.265,
#    1901.165,
#    2026.116,
#    2151.066,
#    2275.967,
#    2400.867,
#    2526.121,
#    2651.375,
#    2776.329,
#    2901.283,
#    3026.187,
#    3151.091,
#    3276.045,
#    3400.999,
#    3526.202,
#    3651.405,
#    3776.359,
#    3901.312,
#    4026.215,
#    4151.118,
#    4276.071,
#    4401.024,
#    4526.278,
#    4651.532,
#    4776.436,
#    4901.34,
#    5026.294,
#    5151.248,
#    5276.152,
#    5401.056,
#    5526.307,
#    5651.558,
#    5776.459,
#    5901.36,
#    6026.311,
#    6151.262,
#    6276.163,
#    6401.064,
#    6526.315,
#    6651.566,
#    6776.467,
#    6901.368,
#    7026.319,
#    7151.27,
#    7276.171,
#    7401.072,
#    7526.326,
# ...

# %%
ppl.extract(1)

# %%
import matplotlib.pyplot as plt
# %matplotlib nbagg
plt.plot(ppl.geometries['old_offshore'][0], ppl.ys[1][-1])
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt4Agg
